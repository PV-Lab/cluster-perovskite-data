# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

folder = './Data/XRD'

files = list(os.walk(folder))[0][2]

print('Files to read: ', files)

a = pd.DataFrame()

# Extract XRD x and y component.
for file in files:
  a[file +'_x'] = pd.read_csv(folder + '/' + file, sep=' ', names = ['x', 'y'])['x']
  a[file+'_y'] = pd.read_csv(folder + '/' + file, sep=' ', names = ['x', 'y'])['y']
# Out:
# Files to read:  ['c1_Cs25FA50MA25.xy', 'r3_Cs75FA0MA25.xy', 'r2_Cs37FA62MA01.xy', 'r1_Cs67FA24MA10.xy', 'c2_Cs25FA71MA04.xy', 'c3_Cs71FA01MA28.xy']

# %%
# Investigate the raw data files with and without xlim.

file = files[1]

print(file)

file_df = pd.read_csv(folder + '/' + file, sep=' ', names = ['x', 'y'])
file_df.plot(x='x', y='y')
#plt.xlim(8, 15)
# Out:
# r3_Cs75FA0MA25.xy
# <AxesSubplot:xlabel='x'>

# %%
# Scale the data
b = a/a.max()
b
# Out:
#       c1_Cs25FA50MA25.xy_x  c1_Cs25FA50MA25.xy_y  r3_Cs75FA0MA25.xy_x  \
# 0                 0.083445              0.169184             0.083445
# 1                 0.084112              0.180060             0.084112
# 2                 0.084780              0.168580             0.084780
# 3                 0.085447              0.151057             0.085447
# 4                 0.086115              0.133535             0.086115
# ...                    ...                   ...                  ...
# 1369              0.997330              0.016918             0.997330
# 1370              0.997997              0.015106             0.997997
# 1371              0.998665              0.018731             0.998665
# 1372              0.999332              0.025982             0.999332
# 1373              1.000000              0.018731             1.000000
#
#       r3_Cs75FA0MA25.xy_y  r2_Cs37FA62MA01.xy_x  r2_Cs37FA62MA01.xy_y  \
# 0                0.413953              0.154036              0.137528
# 1                0.429457              0.154652              0.152223
# 2                0.382946              0.155268              0.133007
# 3                0.434109              0.155884              0.129992
# 4                0.386047              0.156500              0.152223
# ...                   ...                   ...                   ...
# 1369             0.049612              0.997535              0.026752
# 1370             0.046512              0.998152              0.034288
# 1371             0.069767              0.998768              0.032404
# 1372             0.062016              0.999384              0.032781
# 1373             0.062016              1.000000              0.033911
#
#       r1_Cs67FA24MA10.xy_x  r1_Cs67FA24MA10.xy_y  c2_Cs25FA71MA04.xy_x  \
# 0                 0.154036              0.212621              0.154036
# 1                 0.154652              0.226265              0.154652
# 2                 0.155268              0.207504              0.155268
# 3                 0.155884              0.204662              0.155884
# 4                 0.156500              0.210347              0.156500
# ...                    ...                   ...                   ...
# 1369              0.997535              0.052302              0.997535
# 1370              0.998152              0.067652              0.998152
# 1371              0.998768              0.051734              0.998768
# 1372              0.999384              0.056282              0.999384
# 1373              1.000000              0.065947              1.000000
#
#       c2_Cs25FA71MA04.xy_y  c3_Cs71FA01MA28.xy_x  c3_Cs71FA01MA28.xy_y
# 0                 0.139638              0.083445              0.392481
# 1                 0.167919              0.084112              0.429073
# 2                 0.180734              0.084780              0.422055
# 3                 0.167035              0.085447              0.380952
# 4                 0.160848              0.086115              0.398496
# ...                    ...                   ...                   ...
# 1369              0.026513              0.997330              0.056642
# 1370              0.028281              0.997997              0.052130
# 1371              0.031816              0.998665              0.048120
# 1372              0.036235              0.999332              0.056642
# 1373              0.036677              1.000000              0.059148
#
# [1374 rows x 12 columns]

# %%
# Investigate the results of scaling.
cols = ['c1_Cs25FA50MA25.xy_y', 'c2_Cs25FA71MA04.xy_y', 'c3_Cs71FA01MA28.xy_y']

for i in cols:
  print(a[i])
  print(b[i])
# Out:
# 0       280.0
# 1       298.0
# 2       279.0
# 3       250.0
# 4       221.0
#         ...
# 1369     28.0
# 1370     25.0
# 1371     31.0
# 1372     43.0
# 1373     31.0
# Name: c1_Cs25FA50MA25.xy_y, Length: 1374, dtype: float64
# 0       0.169184
# 1       0.180060
# 2       0.168580
# 3       0.151057
# 4       0.133535
#           ...
# 1369    0.016918
# 1370    0.015106
# 1371    0.018731
# 1372    0.025982
# 1373    0.018731
# Name: c1_Cs25FA50MA25.xy_y, Length: 1374, dtype: float64
# 0       316.0
# 1       380.0
# 2       409.0
# 3       378.0
# 4       364.0
#         ...
# 1369     60.0
# 1370     64.0
# 1371     72.0
# 1372     82.0
# 1373     83.0
# Name: c2_Cs25FA71MA04.xy_y, Length: 1374, dtype: float64
# 0       0.139638
# 1       0.167919
# 2       0.180734
# 3       0.167035
# 4       0.160848
#           ...
# 1369    0.026513
# 1370    0.028281
# 1371    0.031816
# 1372    0.036235
# 1373    0.036677
# Name: c2_Cs25FA71MA04.xy_y, Length: 1374, dtype: float64
# 0       783.0
# 1       856.0
# 2       842.0
# 3       760.0
# 4       795.0
#         ...
# 1369    113.0
# 1370    104.0
# 1371     96.0
# 1372    113.0
# 1373    118.0
# Name: c3_Cs71FA01MA28.xy_y, Length: 1374, dtype: float64
# 0       0.392481
# 1       0.429073
# 2       0.422055
# 3       0.380952
# 4       0.398496
#           ...
# 1369    0.056642
# 1370    0.052130
# 1371    0.048120
# 1372    0.056642
# 1373    0.059148
# Name: c3_Cs71FA01MA28.xy_y, Length: 1374, dtype: float64

# %%
def plotter(axes, cols, colors, offset=0):
  for i in range(len(cols)):
    col = cols[i]
    axes.plot(a[col+'_x'], b[col+'_y'] + offset, label=col.split('.')[0], color=colors[i])
    offset += 1


fig, (ax1, ax2) = plt.subplots(1,2, figsize=(6,6))

cols1 = ['c1_Cs25FA50MA25.xy', 'c2_Cs25FA71MA04.xy', 'c3_Cs71FA01MA28.xy']
cols2 = ['r1_Cs67FA24MA10.xy', 'r2_Cs37FA62MA01.xy', 'r3_Cs75FA0MA25.xy']

offset = 0

# Let's make the right hand side of the plot lighter.
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
for i in range(len(colors)):
    colors.append(np.array(mcolors.to_rgb(colors[i])) + 0.2)
    if i == 1: # Orange gets saturated
        colors[i+3][0] = 1

plotter(ax1, cols1, colors[0:3])
plotter(ax2, cols2, colors[3::])

ax1.set_xlim(8, 15)
ax2.set_xlim(8, 15)

ylim = 4
ax1.set_ylim(0, ylim)
ax2.set_ylim(0, ylim)

ax1.tick_params(left=False, labelleft=False)
ax2.tick_params(left=False, labelleft=False)

ax1.set_ylabel('Intensity')

ax1.set_xlabel(r"2$\Theta$")
ax2.set_xlabel(r"2$\Theta$")

height = -0.4
ax1.legend(loc=(0,height), frameon=False)
ax2.legend(loc=(0,height), frameon=False)


fontsize = 'small'

for i in range(2):
    if i == 0:
        ax = ax1
    else:
        ax = ax2

    if i==0:
        ax.text(9.9, 3.5, r' $ {\rm \delta}$-Cs (002)', c='b', fontsize=fontsize)
    ax.scatter([9.8], [3.5], marker='*', c='b', s=10)
    ax.scatter([9.8], [1.5], marker='*', c='b', s=10)
    ax.scatter([9.8], [0.5], marker='*', c='b', s=10)
    
    if i==0:
        ax.text(12, 2.9, r' ${\rm \delta}$-Cs (102)', c='b', fontsize=fontsize)
    ax.scatter([13], [2.8], marker='*', c='b', s=10)
    if i == 1:
        ax.scatter([13], [1.3], marker='*', c='b', s=10)
        ax.scatter([13], [0.4], marker='*', c='b', s=10)

    if i==0:
        ax.text(12.3, 3.2, r'perovskite', fontsize=fontsize)
    ax.scatter([14.1], [3.2], marker='d', c='k', s=10)
    ax.plot([14.1, 14.1], [0, ylim], '--k', linewidth=0.8)
    
    if i==0:
        ax.text(12.6, 1.5, r' PbI$_2$', c='darkgoldenrod', fontsize=fontsize)
    ax.scatter([12.6], [1.5], marker='h', c='darkgoldenrod', s=10)
    if i == 1:
        ax.scatter([12.6], [0.5], marker='h', c='darkgoldenrod', s=10)

plt.tight_layout()
fig.savefig('xrd_films_clustered.png', dpi = 600, bbox_inches = 'tight')
fig.savefig('xrd_films_clustered.svg', bbox_inches = 'tight')
